# %% [markdown]
# # TD : Initiation à la complexité algorithmique en temps

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# ### 1. Quelle est la complexité temporelle ?

# %% [markdown]
# La complexite temporelle dans le pire des cas est :  O(1)

# %% [markdown]
# ### 2. Pourquoi ne dépend-elle pas de la taille de la liste ?

# %% [markdown]
# il ne depend pas a la taille du list car c'est just une operation de selection est ca revient a (python internals) car le compilateur conaitre la taille du list , et par l'utilisation d'une simple formule mathematique peut arriver a l'adresse memoire de la valeur

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# ### 1. Pourquoi la recherche devient deux fois plus rapide à chaque itération ?

# %% [markdown]
# le recherche devient 2 fois plus rapide car chaque fois la taille de la list est / 2 donc le recherche est simple

# %% [markdown]
# ### 2. Quelle est la complexité temporelle ?

# %% [markdown]
# la complexite dans les pire des cas est O(logn)

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# ### 1. Combien de fois la boucle s’exécute-t-elle pour une liste de taille n ?

# %% [markdown]
# pour une list d'une taille = n , la boucle va etre executer n fois

# %% [markdown]
# ### Quelle est la complexité ?

# %% [markdown]
# la complexite dans les pire des cas est O(n^2) , bien sure on negligent les constant d'association des valeur

# %% [markdown]
# ## Exercice 4

# %% [markdown]
# ### 1. Pourquoi cet algorithme est plus efficace que le tri à bulles ?

# %% [markdown]
# tout simplement car "bubble sort" admis une philosophie c'est de rendre la valeur max (en cas de tri asc) vers l'extremite , est cela signifie que on a beaucoup d'iteration (2 boucles) est ca n'est pas efficace
# mais le "quick sort " admet la philosophie de "devide and conquer" qui plus simple est efficace

# %% [markdown]
# ### 2. Quelle est sa complexité moyenne et pourquoi ?

# %% [markdown]
# la Complexite moyenne ou bien Big Theta de ce Algorithme est Big Theta(nlogn) , n du partitionnement , est log(n) car devise pour arriver aux bas

# %% [markdown]
# ## Exercice 5

# %% [markdown]
# ### 1. Pourquoi y a-t-il deux boucles imbriquées ?

# %% [markdown]
# pour n'est pas toucher les valeur qui sont en extremite car il sont deja triee

# %% [markdown]
# ### 2. Quelle est la complexité en fonction de n ?

# %% [markdown]
# la complexite dans les pire des cas est O(n^2)

# %% [markdown]
# ## Exercice 6

# %% [markdown]
# ### 1. Combien d’appels récursifs pour n = 5 ?

# %% [markdown]
# 15 fois

# %% [markdown]
# ### 2. Pourquoi le temps explose très vite ?

# %% [markdown]
# car c'est une complexite exp O(2^n)

# %% [markdown]
# ## Exercice 7

# %% [markdown]
# ### 1. Combien de permutations pour une liste de 4 éléments ?

# %% [markdown]
# 24

# %% [markdown]
# ### 2. Quelle est la complexité ?

# %% [markdown]
# la complexite est O(n!)
